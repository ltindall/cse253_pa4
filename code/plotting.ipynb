# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure()
loss = np.load('LSTM_1lay_100unit_25seq_1000batch_100epoch_0drop_1temp.npy')
loss2 = np.load('LSTM_1lay_50unit_25seq_1000batch_100epoch_0drop_1temp.npy')
loss3 = np.load('LSTM_1lay_150unit_25seq_1000batch_100epoch_0drop_1temp.npy')
plt.plot(loss2[0,:], label='Train 50 units')
plt.plot(loss[0,:],label='Train 100 units')
plt.plot(loss3[0,:], label='Train 150 units')
plt.plot(loss2[1,:], label = 'Validation 50 units')
plt.plot(loss[1,:],label='Validation 100 units')
plt.plot(loss3[1,:], label = 'Validation 150 units')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title("Loss vs Epochs")
plt.legend()
plt.show()

# %%
plt.figure()
loss = np.load('LSTM_1lay_100unit_25seq_1000batch_100epoch_0drop_1temp.npy')
loss2 = np.load('LSTM_1lay_50unit_25seq_1000batch_100epoch_0drop_1temp.npy')
loss3 = np.load('LSTM_1lay_150unit_25seq_1000batch_100epoch_0drop_1temp.npy')
loss4 = np.load('LSTM_2lay_100unit_25seq_1000batch_100epoch_0drop_1temp.npy')
loss5 = np.load('LSTM_3lay_100unit_25seq_1000batch_100epoch_0drop_1temp.npy')
plt.plot(loss[0,:],label='Train 100 units 1 layer')

plt.plot(loss4[0,:], label='Train 100 units 2 layer')
plt.plot(loss5[0,:], label='Train 100 units 3 layer')
plt.plot(loss[1,:],label='Validation 100 units 1 layer')
plt.plot(loss4[1,:], label='Validation 100 units 2 layer')
plt.plot(loss5[1,:], label='Validation 100 units 3 layer')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title("Loss vs Epochs")
plt.legend()
plt.show()

# %%
plt.figure()
loss = np.load('LSTM_1lay_100unit_25seq_1000batch_100epoch_0drop_1temp.npy')
loss2 = np.load('LSTM_1lay_50unit_25seq_1000batch_100epoch_0drop_1temp.npy')
loss3 = np.load('LSTM_1lay_150unit_25seq_1000batch_100epoch_0drop_1temp.npy')
loss4 = np.load('LSTM_2lay_100unit_25seq_1000batch_100epoch_0drop_1temp.npy')
loss5 = np.load('LSTM_3lay_100unit_25seq_1000batch_100epoch_0drop_1temp.npy')
loss6 = np.load('LSTM_1lay_100unit_25seq_2000batch_100epoch_0drop_1temp.npy')

plt.plot(loss[0,:],label='Train 100 units 1000 batch size')
plt.plot(loss6[0,:], label='Train 100 units 2000 batch size')
#plt.plot(loss5[0,:], label='Train 100 units 3 layer')
plt.plot(loss[1,:],label='Validation 100 units 1000 batch size')
plt.plot(loss6[1,:], label='Validation 100 units 2000 batch size')
#plt.plot(loss5[1,:], label='Validation 100 units 3 layer')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title("Loss vs Epochs")
plt.legend()
plt.show()

# %%
plt.figure()
loss = np.load('LSTM_1lay_100unit_25seq_1000batch_100epoch_0drop_1temp.npy')
loss2 = np.load('LSTM_1lay_100unit_25seq_1000batch_100epoch_0.1drop_1temp.npy')
loss3 = np.load('LSTM_1lay_100unit_25seq_1000batch_100epoch_0.2drop_1temp.npy')
loss4 = np.load('LSTM_1lay_100unit_25seq_1000batch_100epoch_0.3drop_1temp.npy')

plt.plot(loss[0,:],label='Train 0 dropout')
plt.plot(loss2[0,:], label='Train 0.1 dropout')
plt.plot(loss3[0,:], label='Train 0.2 dropout')
plt.plot(loss4[0,:], label='Train 0.3 dropout')

plt.plot(loss[1,:],label='Validation 0 dropout')
plt.plot(loss2[1,:], label='Validation 0.1 dropout')
plt.plot(loss3[1,:], label='Validation 0.2 dropout')
plt.plot(loss4[1,:], label='Validation 0.3 dropout')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title("Loss vs Epochs")
plt.legend()
plt.show()
